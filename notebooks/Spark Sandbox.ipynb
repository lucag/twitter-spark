# %%
sc

# %%
from pyspark import SparkContext
from pyspark.streaming import StreamingContext

# Create a local StreamingContext with two working thread and batch interval of 1 second
ssc = StreamingContext(sc, 1)

# %%
# Create a DStream that will connect to hostname:port, like localhost:9999
lines = ssc.socketTextStream('localhost', 10101)

# %%
# Split each line into words
words = lines.flatMap(lambda line: line.split(' '))

# %%
# Count each word in each batch
pairs = words.map(lambda word: (word, 1))
wordCounts = pairs.reduceByKey(lambda x, y: x + y)

# Print the first ten elements of each RDD generated in this DStream to the console
wordCounts.pprint()

# %%
ssc.start()             # Start the computation
#ssc.awaitTermination()  # Wait for the computation to terminate
# Out:
# -------------------------------------------
# Time: 2016-02-01 20:09:32
# -------------------------------------------
#
# -------------------------------------------
# Time: 2016-02-01 20:09:33
# -------------------------------------------
#
# -------------------------------------------
# Time: 2016-02-01 20:09:34
# -------------------------------------------
#
# -------------------------------------------
# Time: 2016-02-01 20:09:35
# -------------------------------------------
#
# -------------------------------------------
# Time: 2016-02-01 20:09:36
# -------------------------------------------
#
# -------------------------------------------
# Time: 2016-02-01 20:09:37
# -------------------------------------------
#
# -------------------------------------------
# Time: 2016-02-01 20:09:38
# -------------------------------------------
#
# -------------------------------------------
# Time: 2016-02-01 20:09:39
# -------------------------------------------
#
# ...

# %%
ssc.stop()
# Out:
# -------------------------------------------
# Time: 2016-02-01 20:10:33
# -------------------------------------------

# %%
import sqlite3

# %%
conn = sqlite3.connect('../data/airline-twitter-sentiment/database.sqlite')

# %%
ts = list(conn.execute('select airline_sentiment, negativereason, text from tweets'))

# %%
from IPython.display import HTML
td = lambda x: '<td>%s</td>'% x
tr = lambda x: '<tr>%s</tr>'% x
table = lambda x: '<table>%s</table>' % x

# %%
HTML(table('\n'.join(tr('\n'.join(td(f) for f in rec)) 
                     for rec in ts[:10])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f78a08d9df5b> in <module>()
# ----> 1 HTML(table('\n'.join(tr('\n'.join(td(f) for f in rec))
#       2                      for rec in ts[:10])))
#
# NameError: name 'HTML' is not defined
